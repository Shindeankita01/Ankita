# %% [markdown]
# <a href="https://colab.research.google.com/github/Shindeankita01/Ankita/blob/main/Generative_AI_masterclass.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x= 10

# %%
y=20

# %%
z= x+y

# %%
print(z)
# Out:
# 30

# %%
#to bring a model from hugging face to google colab
from transformers import pipeline

# %%
sentiment_analyzer= pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# ...

# %%
sentiment_analyzer("You are a bad person")
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9993019104003906}]

# %%
sentiment_analyzer("This is a masterclass on Generative AI, and the learners are asking doubts")
# Out:
# [{'label': 'POSITIVE', 'score': 0.9840496778488159}]

# %%
sentiment_analyzer("This is a masterclass on Generative AI, and the learners are asking irreleVENT doubts")
# Out:
# [{'label': 'POSITIVE', 'score': 0.9321469664573669}]

# %%
sentiment_analyzer("This is a masterclass on Generative AI, and the NOT FOCUSED learners are asking irreleVENT doubts")
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9704880118370056}]

# %%
sentiment_analyzer("You are a bad sports player but good person!")
# Out:
# [{'label': 'POSITIVE', 'score': 0.9991422891616821}]

# %%
texts = [
    "I absolutely loved this product! Highly recommended.",
    "The service was terrible and I'm never coming back.",
    "It was okay, nothing special but did the job.",
    "I absolutely loved this product! Highly recommended.",
    "The service was terrible and I'm never coming back.",
    "It was okay, nothing special but did the job.",
    "I absolutely loved this product! Highly recommended.",
    "The service was terrible and I'm never coming back.",
    "It was okay, nothing special but did the job.",
    "I absolutely loved this product! Highly recommended.",
    "The service was terrible and I'm never coming back.",
    "It was okay, nothing special but did the job."
    ,
    "I absolutely loved this product! Highly recommended.",
    "The service was terrible and I'm never coming back.",
    "It was okay, nothing special but did the job.",
    "I absolutely loved this product! Highly recommended.",
    "The service was terrible and I'm never coming back.",
    "It was okay, nothing special but did the job."
]

# %%
for i in range(1,6):
  print("Hi")
# Out:
# Hi
# Hi
# Hi
# Hi
# Hi

# %%
for i in texts:
  print(i,"----------")
# Out:
# I absolutely loved this product! Highly recommended. ----------
# The service was terrible and I'm never coming back. ----------
# It was okay, nothing special but did the job. ----------

# %%
#task is to pickup everything from my list and send it to my sentiment analyzer

# %%
for i in texts:
  print(i,"----", sentiment_analyzer(i))
# Out:
# I absolutely loved this product! Highly recommended. ---- [{'label': 'POSITIVE', 'score': 0.9998818635940552}]
# The service was terrible and I'm never coming back. ---- [{'label': 'NEGATIVE', 'score': 0.9974111914634705}]
# It was okay, nothing special but did the job. ---- [{'label': 'POSITIVE', 'score': 0.9992420673370361}]
# I absolutely loved this product! Highly recommended. ---- [{'label': 'POSITIVE', 'score': 0.9998818635940552}]
# The service was terrible and I'm never coming back. ---- [{'label': 'NEGATIVE', 'score': 0.9974111914634705}]
# It was okay, nothing special but did the job. ---- [{'label': 'POSITIVE', 'score': 0.9992420673370361}]
# I absolutely loved this product! Highly recommended. ---- [{'label': 'POSITIVE', 'score': 0.9998818635940552}]
# The service was terrible and I'm never coming back. ---- [{'label': 'NEGATIVE', 'score': 0.9974111914634705}]
# It was okay, nothing special but did the job. ---- [{'label': 'POSITIVE', 'score': 0.9992420673370361}]
# ...

# %%
#analyse the reviews on amazon and give summary in the end

# %%
#Classifications - News- politics, sports, technology

classifier = pipeline("zero-shot-classification")
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli and revision d7645e1 (https://huggingface.co/facebook/bart-large-mnli).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu

# %%
text = "NASA successfully launched the new James Webb telescope."

labels=["space", "politics", "sports", "technology", "entertainment"]

# %%
classifier(text,labels)
# Out:
# {'sequence': 'NASA successfully launched the new James Webb telescope.',
#  'labels': ['technology', 'space', 'entertainment', 'sports', 'politics'],
#  'scores': [0.6162862777709961,
#   0.3652797341346741,
#   0.011022759601473808,
#   0.004856396000832319,
#   0.00255483016371727]}

# %%
from transformers import pipeline
pipe = pipeline("text-classification", model="roberta-base-openai-detector")
print(pipe("Hello world! Is this content AI-generated?"))  # [{'label': 'Real', 'score': 0.8036582469940186}]
# Out:
# config.json:   0%|          | 0.00/624 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/501M [00:00<?, ?B/s]
# Some weights of the model checkpoint at roberta-base-openai-detector were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# ...

# %%
print(pipe("Hello world! are these learners good or bad"))  # [{'label': 'Real', 'score': 0.8036582469940186}]
# Out:
# [{'label': 'Fake', 'score': 0.6950532793998718}]
